# %% [markdown]
# <a href="https://colab.research.google.com/github/itsmaul/bangkit-capstone/blob/main/CleanforAnomaly_TrainingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import numpy as np
import pandas as pd

# %%
def preprocess_data(data):
    # Menghitung total_income dan total_expense
    data['income'] = data.apply(lambda x: x['amount'] if x['transaction_type'] == 'Income' else 0, axis=1)
    data['expense'] = data.apply(lambda x: x['amount'] if x['transaction_type'] == 'Expense' else 0, axis=1)

    # Memisahkan data untuk income dan expense
    income_df = data[['date', 'income']].copy()
    expense_df = data[['date', 'expense']].copy()

    # Menghapus baris yang tidak memiliki nilai (nilai 0) pada masing-masing DataFrame
    income_df = income_df[income_df['income'] > 0]
    expense_df = expense_df[expense_df['expense'] > 0]

    return income_df, expense_df

# %%
merger_df = pd.read_json("merger_dataset.json")

# %%
income_df, expense_df = preprocess_data(merger_df)

# %%
income_df.sample(20)
# Out:
#           date   income
# 522 2024-10-21   247000
# 486 2024-09-24   100000
# 190 2024-03-21   200000
# 163 2024-03-01  1200000
# 114 2024-01-30   300000
# 494 2024-10-03  1200000
# 141 2024-02-13   100000
# 373 2024-07-15    50000
# 45  2023-10-25    10000
# 112 2024-01-29  2735000
# 215 2024-04-03   500000
# 451 2024-08-28    14000
# 561 2024-11-03   800000
# 231 2024-04-13   100101
# 450 2024-08-27   150000
# 153 2024-02-24   200000
# 441 2024-08-20   350000
# 560 2024-11-02   100000
# 352 2024-07-01  1200000
# 433 2024-08-17   300000

# %%
expense_df.sample(20)
# Out:
#           date  expense
# 102 2024-01-20     6000
# 87  2024-01-09     1000
# 556 2024-11-02   330000
# 472 2024-09-13     1500
# 133 2024-02-04     1000
# 591 2024-11-12     1500
# 266 2024-05-05    32000
# 469 2024-09-13    20000
# 333 2024-06-20    16900
# 254 2024-04-29   164000
# 66  2023-12-20   300000
# 465 2024-09-12    19800
# 119 2024-02-02     1500
# 142 2024-02-15   200000
# 513 2024-10-19     7500
# 25  2023-09-18   250130
# 384 2024-07-22   100000
# 94  2024-01-13   200000
# 539 2024-10-30   120000
# 77  2024-01-02   100000

# %%
# Simpan 'income_df' ke file JSON
with open('income_data.json', 'w') as json_file:
    income_df['date'] = pd.to_datetime(income_df['date'])
    income_df['date'] = income_df['date'].dt.strftime('%Y-%m-%d')
    json.dump(income_df.to_dict(orient="records"), json_file, indent=1)

# Simpan 'expense_df' ke file JSON
with open('expense_data.json', 'w') as json_file:
    expense_df['date'] = pd.to_datetime(expense_df['date'])
    expense_df['date'] = expense_df['date'].dt.strftime('%Y-%m-%d')
    json.dump(expense_df.to_dict(orient="records"), json_file, indent=1)
